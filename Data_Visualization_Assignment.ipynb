# %% [markdown]
# <a href="https://colab.research.google.com/github/sehgalsakshi/New-Repository/blob/master/Data_Visualization_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##*Data Visualization Assignment*

# %% [markdown]
# In this assignment students have to transform iris data into 3 dimensions
#
# ---
#
#
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
X,y  = datasets.load_iris().data, datasets.load_iris().target

# %%
X[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
PCA = decomposition.PCA(n_components=3)

# %%
PCA
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
X = PCA.fit_transform(X)

# %%
X[:5]
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483],
#        [-2.71414169, -0.17700123, -0.21046427],
#        [-2.88899057, -0.14494943,  0.01790026],
#        [-2.74534286, -0.31829898,  0.03155937],
#        [-2.72871654,  0.32675451,  0.09007924]])

# %%
X = pd.DataFrame(X, columns=['PCA1', 'PCA2', 'PCA3'])

# %%
X
# Out:
#          PCA1      PCA2      PCA3
# 0   -2.684126  0.319397 -0.027915
# 1   -2.714142 -0.177001 -0.210464
# 2   -2.888991 -0.144949  0.017900
# 3   -2.745343 -0.318299  0.031559
# 4   -2.728717  0.326755  0.090079
# ..        ...       ...       ...
# 145  1.944110  0.187532  0.177825
# 146  1.527167 -0.375317 -0.121898
# 147  1.764346  0.078859  0.130482
# 148  1.900942  0.116628  0.723252
# 149  1.390189 -0.282661  0.362910
#
# [150 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = X.PCA1
xline = X.PCA2
yline = X.PCA3
ax.scatter3D(xline, yline, zline, c=y);
